# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Tavo29U9IcOrqHvLsc03")
project = rf.workspace("cyh").project("salad-ax2ax")
dataset = project.version(1).download("yolov5")

# %%
import torch
from IPython.display import Image, clear_output
from PIL import Image as img
print(img.open('/content/salad-1/train/images/0218919b1efedc7d_jpg.rf.bc3e7551ea44ddc77bffa9858c08c9a6.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=702x938 at 0x7F2F4CE0D950>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = '/content/salad-1/train/images/0218919b1efedc7d_jpg.rf.bc3e7551ea44ddc77bffa9858c08c9a6.jpg'

img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=702x938 at 0x7F2F4E661B90>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Tavo29U9IcOrqHvLsc03")
project = rf.workspace("test-on9hk").project("vegetables-kacga")
dataset = project.version(5).download("yolov5")

# %%
import torch
from IPython.display import Image, clear_output
from PIL import Image as img
print(img.open('/content/Vegetables-5/train/images/--------------------------1_jpg.rf.bfbd8f40e331b0f11e54a526f7472d9f.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=608x608 at 0x7F2F4E667910>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = '/content/Vegetables-5/train/images/--------------------------1_jpg.rf.bfbd8f40e331b0f11e54a526f7472d9f.jpg'

img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=608x608 at 0x7F2F4E667590>
