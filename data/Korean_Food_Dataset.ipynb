# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Tavo29U9IcOrqHvLsc03")
project = rf.workspace("heasun8583-gmail-com").project("korean-food_yolov5")
dataset = project.version(6).download("yolov5")

# %%
import torch
from IPython.display import Image, clear_output
from PIL import Image as img
print(img.open('/content/Korean-Food_yolov5-6/train/images/----_jpeg.rf.472d09b3377e79493f97a0fd17aff786.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F944C868890>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = '/content/Korean-Food_yolov5-6/train/images/----_jpeg.rf.472d09b3377e79493f97a0fd17aff786.jpg'

img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F944C79BE90>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Tavo29U9IcOrqHvLsc03")
project = rf.workspace("chungbuk-university").project("food_korea6")
dataset = project.version(16).download("yolov5")

# %%
import torch
from IPython.display import Image, clear_output
from PIL import Image as img
print(img.open('/content/FOOD_KOREA6-16/valid/images/Korean-roll-Gimbap-kimbob--made-from-steamed-white--3-_jpg.rf.c022e97984612f859e81fd48978fd50a.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F944C736AD0>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = '/content/FOOD_KOREA6-16/valid/images/Korean-roll-Gimbap-kimbob--made-from-steamed-white--3-_jpg.rf.c022e97984612f859e81fd48978fd50a.jpg'

img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F944C736850>
